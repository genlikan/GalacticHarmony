# %% [markdown]
# **Stellar Classification Project**
#
# The categorization of stars, galaxies, and quasars based on their spectral properties is a crucial concept in astronomy. By dividing stars into different categories based on factors such as their temperature, luminosity, and chemical composition, we can gain insight into their physical properties and evolutionary stages. Early cataloging efforts of stars and their positioning in the sky led to the discovery that they were part of our own galaxy, and as telescopes became more advanced, it was determined that other galaxies existed, such as Andromeda, which sparked further study.
#
# **Objective**: This project aims to classify stars, galaxies, and quasars according to their spectral properties in the provided dataset (in the shared drive).
#
# **Requirement**:
#
# (1) You need include the major compoment of machine learning problems, such as exploring the data (e.g., data statistic, visualization, etc.), data processing (such as, data split, feature selection, etc.), classification model selection, model performance evaluation (use accuracy and confusion matrix), and final classification.
#
# (2) In the classification model selection part, at least three different classification models should be analyzed. It is necessary to adjust the parameters of each classification model to have a better performance.
#
# (3) The performance of your model(s) will affect your result. The best classification will get 5 bonus points, and the worst classification will lose 5 points.
#
# Deadline: 3:00 PM, October 31st (Tuesday)

# %% [markdown]
# **Column information**
#
# *   **obj_ID**: Object Identifier is a unique value that identifies the object in the image catalog used by the Sloan Digital Sky Survey (SDSS) data archive.
#
# *   **alpha**: Right Ascension angle (in degrees) at J2000 epoch, which is a coordinate system commonly used in astronomy to describe the position of celestial objects in the sky.
#
# *   **delta**: Declination angle (in degrees) at J2000 epoch, which is another coordinate system commonly used in astronomy to describe the position of celestial objects in the sky.
#
# *   **u, g, r, i, z**: These are photometric filters used in the SDSS system to measure the amount of light from objects in different wavelength bands. Each filter corresponds to a different color of light, with u being in the ultraviolet range, g in green, r in red, i in near-infrared, and z in infrared.
#
# *   **run_ID**: Run Number is used to identify the specific scan of the sky made by SDSS. Each scan covers a specific area of the sky and is assigned a unique run number.
#
# *   **rereun_ID**: Rerun Number is used to specify how the image was processed, such as the version of the software or the calibration used to create the image.
#
# *   **cam_col**: Camera column is used to identify the scanline within the run. Each scan is divided into multiple camera columns to cover a larger area of the sky.
#
# *   **field_ID**: Field Number is used to identify each field in the scan, which is a smaller area within the camera column.
#
# *   **spec_obj_ID**: Unique ID used for optical spectroscopic objects. This means that two different observations with the same spec_obj_ID must share the output class, which is either a galaxy, star, or quasar.
#
# *   **class**: Object class is the classification assigned to the object based on its spectral properties, which can be a galaxy, star, or quasar.
#
# *   **redshift**: Redshift value is based on the increase in wavelength of light emitted by the object due to its motion away from or towards the observer. It is a measure of how much the universe has expanded since the light was emitted by the object.
#
# *   **plate**: Plate ID identifies each plate used in the SDSS spectroscopic survey. Each plate contains multiple fibers that collect the light from different objects.
#
# *   **MJD**: Modified Julian Date is used to indicate when a given piece of SDSS data was taken. It is a modified version of the Julian Date, which is a way to represent dates and times in astronomy.
#
# *   **fiber_ID**: Fiber ID identifies the fiber that pointed the light at the focal plane in each observation. Each fiber collects the light from a different object, allowing SDSS to observe multiple objects simultaneously.

# %% [markdown]
# **Understanding Quasars, Stars and Galaxies**
#
# **Quasars**:
#
# A quasar is an extremely luminous active galactic nucleus (AGN). It is pronounced /ˈkweɪzɑːr/ KWAY-zar, and sometimes known as a quasi-stellar object, abbreviated QSO. This emission from an AGN is powered by a supermassive black hole with a mass ranging from millions to tens of billions of solar masses, surrounded by a gaseous accretion disc. Gas in the disc falling towards the black hole heats up because of friction and releases energy in the form of electromagnetic radiation. The radiant energy of quasars is enormous; the most powerful quasars have luminosities thousands of times greater than that of a galaxy such as the Milky Way.
# ![Quasar](https://drive.google.com/uc?export=view&id=1os1sYipIhM-fSKy8OISVQ68Ev_KPF6N9)
#
# **Stars**:
#
# A star's life begins with the gravitational collapse of a gaseous nebula of material composed primarily of hydrogen, along with helium and trace amounts of heavier elements. Its total mass is the main factor determining its evolution and eventual fate. A star shines for most of its active life due to the thermonuclear fusion of hydrogen into helium in its core. This process releases energy that traverses the star's interior and radiates into outer space. At the end of a star's lifetime, its core becomes a stellar remnant: a white dwarf, a neutron star, or—if it is sufficiently massive—a black hole.
# ![Star](https://drive.google.com/uc?export=view&id=1k2uadEOVqmdeAJwHWigIhoivig-0FQsL)
#
# **Galaxies**:
#
# A galaxy is a system of stars, stellar remnants, interstellar gas, dust, dark matter, bound together by gravity.[1][2] The word is derived from the Greek galaxias (γαλαξίας), literally 'milky', a reference to the Milky Way galaxy that contains the Solar System. Galaxies, averaging an estimated 100 million stars,[3] range in size from dwarfs with less than a hundred million stars, to the largest galaxies known – supergiants with one hundred trillion stars,[4] each orbiting its galaxy's center of mass. Most of the mass in a typical galaxy is in the form of dark matter, with only a few percent of that mass visible in the form of stars and nebulae. Supermassive black holes are a common feature at the centres of galaxies.
# ![Galaxy](https://drive.google.com/uc?export=view&id=14CqDjOEGros3rVcXILjpz9V6BjIrgxDG)

# %% [markdown]
# **Import Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import  mean_squared_error, r2_score
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

data = pd.read_csv("star_classification.csv")

# %% [markdown]
# **Data Exploration**
#
# Include, at least, data statistics and visualization

# %%
# show first 5 rows
data.head()
# Out:
#          obj_ID       alpha      delta         u         g         r  \
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0  19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1  21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2  19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3  20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4  15.97711  15.54461    8102       301        3       137  6.891865e+18
#
#     class  redshift  plate    MJD  fiber_ID
# 0  GALAXY  0.634794   5812  56354       171
# ...

# %%
# Columns to remove
columns_to_remove = ['obj_ID','run_ID', 'rerun_ID','cam_col' ,'field_ID', 'spec_obj_ID', 'plate', 'fiber_ID']

# Removing the specified columns
data.drop(columns=columns_to_remove, inplace=True)

# %%
data["class"].unique()
# Out:
# array(['GALAXY', 'QSO', 'STAR'], dtype=object)

# %%
data.head()
# Out:
#         alpha      delta         u         g         r         i         z  \
# 0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454  19.25010
# 4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
#
#     class  redshift    MJD
# 0  GALAXY  0.634794  56354
# 1  GALAXY  0.779136  58158
# 2  GALAXY  0.644195  55592
# 3  GALAXY  0.932346  58039
# 4  GALAXY  0.116123  56187

# %% [markdown]
# **Data Pre-Processing**
#
# For example, scaling, split data, feature selection, feature design, etc.
#
# Feature selection should have clear evidence.

# %%
#Seperate the features and labels
X = data.drop('class', axis=1)
y = data['class']


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures

poly = PolynomialFeatures(degree=3, include_bias=False)
X2 = poly.fit_transform(X_train)

# %%
X.head()
# Out:
#         alpha      delta         u         g         r         i         z  \
# 0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454  19.25010
# 4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
#
#    redshift    MJD
# 0  0.634794  56354
# 1  0.779136  58158
# 2  0.644195  55592
# 3  0.932346  58039
# 4  0.116123  56187

# %%
y.head()
# Out:
# 0    GALAXY
# 1    GALAXY
# 2    GALAXY
# 3    GALAXY
# 4    GALAXY
# Name: class, dtype: object

# %% [markdown]
# **Model Selection**
#
# For example, ridge classification, discriminant analysis, decision tree, nearest neighbours, neural network, etc.

# %% [markdown]
# **Model Performance Evaluation**
#
# Use accuracy and confusion matrix to estimate your model performance. Other visual method should be helpful also.

# %% [markdown]
# **Final Result Presentation**
#
# Present your final results (classification model, model performance, alues, plots, etc.)

# %%
import pandas as pd
file_path = 'star_classification.csv'
data = pd.read_csv(file_path)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# Encoding the 'class' column
label_encoder = LabelEncoder()
data['class_encoded'] = label_encoder.fit_transform(data['class'])

# Selecting relevant features for classification
# Assuming 'u', 'g', 'r', 'i', 'z', and 'redshift' are the relevant features for classification
features = data[['u', 'g', 'r', 'i', 'z', 'redshift']]
target = data['class_encoded']

# Scaling the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.3, random_state=42)

# Outputting the shape of the training and testing sets
(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# ((70000, 6), (30000, 6), (70000,), (30000,))

# %%
data['class_encoded'].unique()
# Out:
# array([0, 1, 2])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# Training a Random Forest Classifier
random_forest_model = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest_model.fit(X_train, y_train)

# Predicting on the test set
y_pred = random_forest_model.predict(X_test)

# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred, target_names=label_encoder.classes_)

print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.9776666666666667

# %%
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.99      0.98     17845
#          QSO       0.97      0.92      0.94      5700
#         STAR       1.00      1.00      1.00      6455
#
#     accuracy                           0.98     30000
#    macro avg       0.98      0.97      0.97     30000
# weighted avg       0.98      0.98      0.98     30000

# %% [markdown]
# # **DATA STATS METHODS**
#
#
# ---
#
#
# * Data Distribution, Regression, and Correlation
#
# * ANOVA and Classification
#
# * Linear Discriminant Analysis
#
# * k-Nearest Neighbors
#
# * Linear Model Selection and Regularization
#
# * ~~Support Vector Machines~~
#
# * ~~Unsupervised learning~~
#
# * Principal Component Analysis
#
# * Clustering

# %%
X_train.shape, y_train.shape
# Out:
# ((70000, 6), (70000,))

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Training a Linear Regression model
linear_regression_model = LinearRegression()
linear_regression_model.fit(X_train, y_train)

# Predicting on the test set
y_pred_lr = linear_regression_model.predict(X_test)

# Since Linear Regression predicts continuous values, we need to map these back to discrete class labels
# The closest integer to the prediction will be considered as the class label
y_pred_lr_classified = np.rint(y_pred_lr).astype(int)

# Clipping predictions to ensure they fall within the range of encoded class labels
y_pred_lr_classified = np.clip(y_pred_lr_classified, 0, len(label_encoder.classes_) - 1)

# Evaluating the model (Note: Standard classification metrics may not be entirely appropriate)
accuracy_lr = accuracy_score(y_test, y_pred_lr_classified)
classification_rep_lr = classification_report(y_test, y_pred_lr_classified, target_names=label_encoder.classes_)

print(accuracy_lr)
# Out:
# 0.5259

# %%
print(classification_rep_lr)
# Out:
#               precision    recall  f1-score   support
#
#       GALAXY       0.86      0.58      0.70     17845
#          QSO       0.29      0.91      0.44      5700
#         STAR       0.70      0.03      0.05      6455
#
#     accuracy                           0.53     30000
#    macro avg       0.62      0.51      0.40     30000
# weighted avg       0.72      0.53      0.51     30000

# %%
from sklearn.linear_model import LogisticRegression

# Training a Multinomial Logistic Regression model
logistic_regression_model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000, random_state=42)
logistic_regression_model.fit(X_train, y_train)

# Predicting on the test set
y_pred_log_reg = logistic_regression_model.predict(X_test)

# Evaluating the model
accuracy_log_reg = accuracy_score(y_test, y_pred_log_reg)
classification_rep_log_reg = classification_report(y_test, y_pred_log_reg, target_names=label_encoder.classes_)

print(accuracy_log_reg)
# Out:
# 0.9531666666666667

# %%
print(classification_rep_log_reg)
# Out:
#               precision    recall  f1-score   support
#
#       GALAXY       0.96      0.96      0.96     17845
#          QSO       0.95      0.87      0.91      5700
#         STAR       0.94      1.00      0.97      6455
#
#     accuracy                           0.95     30000
#    macro avg       0.95      0.94      0.95     30000
# weighted avg       0.95      0.95      0.95     30000

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
# Simplifying the approach further by using only one feature for polynomial transformation
single_feature_index = 0  # Using only the first feature for this demonstration

# Redefining the pipeline with polynomial features (degree 2) and linear regression
polynomial_regression_single_feature = Pipeline([
    ('poly_features', PolynomialFeatures(degree=5, include_bias=False)),
    ('linear_regression', LinearRegression())
])

# Training the model on a single feature
polynomial_regression_single_feature.fit(X_train[:, single_feature_index:single_feature_index+1], y_train)

# Predicting on the test set using the same single feature
y_pred_poly_single = polynomial_regression_single_feature.predict(X_test[:, single_feature_index:single_feature_index+1])

# Visualizing the relationship between the selected feature and the target
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(X_train[:, single_feature_index], y_train, color='blue', label='Training Data')
plt.scatter(X_test[:, single_feature_index], y_test, color='green', label='Test Data')
plt.plot(X_test[:, single_feature_index], y_pred_poly_single, color='red', label='Model Predictions')
plt.xlabel('Selected Feature')
plt.ylabel('Target')
plt.title('Polynomial Regression with Single Feature')
plt.legend()
plt.show()

# %%
# Mapping encoded class labels back to original class names for visualization
y_train_classes = label_encoder.inverse_transform(y_train)
y_test_classes = label_encoder.inverse_transform(y_test)

# Feature names for visualization
feature_names = ['u', 'g', 'r', 'i', 'z', 'redshift']

# Creating scatter plots for each feature against the target variable
plt.figure(figsize=(15, 10))
for i, feature_name in enumerate(feature_names):
    plt.subplot(2, 3, i+1)
    for class_name in label_encoder.classes_:
        # Selecting data points belonging to the current class
        idx_train = y_train_classes == class_name
        idx_test = y_test_classes == class_name

        # Scatter plot for training data
        plt.scatter(X_train[idx_train, i], y_train[idx_train], label=f'{class_name} (Train)', alpha=0.7)

        # Scatter plot for testing data
        plt.scatter(X_test[idx_test, i], y_test[idx_test], label=f'{class_name} (Test)', alpha=0.7)

    plt.xlabel(feature_name)
    plt.ylabel('Class')
    plt.title(f'Feature: {feature_name}')
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-27-c23235fbf5d5>:28: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()

# %%
data["u"]
# Out:
# 0        23.87882
# 1        24.77759
# 2        25.26307
# 3        22.13682
# 4        19.43718
#            ...
# 99995    22.16759
# 99996    22.69118
# 99997    21.16916
# 99998    25.35039
# 99999    22.62171
# Name: u, Length: 100000, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
# data = pd.read_excel('path_to_your_file.xlsx')

# List of feature names you want to plot
feature_names = ['u', 'g', 'r', 'i', 'z', 'redshift']

# Creating scatter plots for each feature
for feature_name in feature_names:
    plt.figure(figsize=(8, 6))
    plt.scatter(range(len(data)), data[feature_name], alpha=0.5)
    plt.xlabel('Index')
    plt.ylabel(feature_name)
    plt.title(f'Scatter Plot of {feature_name}')
    plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
# data = pd.read_excel('path_to_your_file.xlsx')

# List of feature names you want to plot
feature_names = ['u', 'g', 'r', 'i', 'z', 'redshift']

# Creating scatter plots for each feature
for feature_name in feature_names:
    plt.figure(figsize=(8, 6))
    plt.scatter(range(len(data)), data[feature_name], alpha=0.5)
    plt.xlabel('Index')
    plt.ylabel(feature_name)
    plt.title(f'Scatter Plot of {feature_name}')
    plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
# data = pd.read_excel('path_to_your_file.xlsx')

# List of feature names for which you want to plot the distribution
feature_names = ['u', 'g', 'r', 'i', 'z', 'redshift']

# Creating histograms for each feature
for feature_name in feature_names:
    plt.figure(figsize=(8, 6))
    plt.hist(data[feature_name], bins=30, edgecolor='black')
    plt.xlabel(feature_name)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {feature_name}')
    plt.show()

# %%
import statsmodels.api as sm
import pandas as pd

# Load your dataset
# data = pd.read_excel('path_to_your_file.xlsx')

# Creating a binary target variable: 1 if the class is 'Quasar', 0 otherwise
data['is_quasars'] = (data['class'] == 'QSO').astype(int)

# Independent variables
X = data[['u', 'g', 'r', 'i', 'z', 'redshift']]  # Assuming these are the relevant features

# Dependent variable
y = data['is_quasars']

# Adding a constant to the model (for the intercept)
X = sm.add_constant(X)

# Fitting the Logistic Regression model
model = sm.Logit(y, X)
result = model.fit()

# Getting the summary of the model
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.108685
#          Iterations 9
#                            Logit Regression Results
# ...
# Dep. Variable:             is_quasars   No. Observations:               100000
# Model:                          Logit   Df Residuals:                    99993
# Method:                           MLE   Df Model:                            6
# Date:                Fri, 08 Dec 2023   Pseudo R-squ.:                  0.7762
# Time:                        03:52:15   Log-Likelihood:                -10868.
# converged:                       True   LL-Null:                       -48566.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.2852      0.275     19.237      0.000       4.747       5.824
# ...

# %%
import numpy as np

def predict_quasar_probability(u, g, r, i, z, redshift):
    logit_p = 5.2852 + (-0.5225 * u) + (-0.3172 * g) + (-1.0908 * r) + (0.6483 * i) + (0.8398 * z) + (6.1623 * redshift)
    probability = 1 / (1 + np.exp(-logit_p))
    return probability

# Example usage:
probability = predict_quasar_probability(u=23.87882, g=22.27530, r=20.39501, i=19.16573, z=18.79371, redshift=0.634794)
print("Probability of being a quasar:", probability)
# Out:
# Probability of being a quasar: 0.012319279245458475

# %%
data[data["is_quasars"]==1].head()
# Out:
#           obj_ID       alpha      delta         u         g         r  \
# 5   1.237680e+18  340.995121  20.589476  23.48827  23.33776  21.32195
# 6   1.237679e+18   23.234926  11.418188  21.46973  21.17624  20.92829
# 17  1.237679e+18    1.494389   3.291746  20.38562  20.40514  20.29996
# 23  1.237658e+18  145.883006  47.300484  21.73992  21.53095  21.26763
# 33  1.237679e+18   20.052556  11.497881  21.89214  21.35124  21.18755
#
#            i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 5   20.25615  19.54544    8102       301        3       110  5.658977e+18
# 6   20.60826  20.42573    7773       301        2       462  1.246262e+19
# 17  20.05918  19.89044    7712       301        5       339  9.843824e+18
# 23  21.36257  21.15861    2821       301        2        33  8.228240e+18
# 33  20.84300  20.76580    7773       301        2       441  1.246830e+19
#
#    class  redshift  plate    MJD  fiber_ID  is_galaxy  is_quasars
# ...

# %%
probability = predict_quasar_probability(u=21.73992	, g=21.53095, r=21.26763, i=21.36257, z=21.15861, redshift=2.075680)
print("Probability of being a quasar:", probability)
# Out:
# Probability of being a quasar: 0.9997532927302057

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset
data = pd.read_csv("star_classification.csv")

# Selecting a subset of features for the pairplot
# Replace with the features you are interested in
selected_features = ['u', 'g', 'r', 'i', 'z', 'redshift', 'class']

# Creating the pairplot
sns.pairplot(data[selected_features], hue='class', diag_kind='kde', plot_kws={'alpha': 0.6, 's': 80, 'edgecolor': 'k'}, size=2)

# Display the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import pandas as pd

# Load the dataset
file_path = 'star_classification.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data.head()

# Check for missing values
missing_values = data.isnull().sum()

# Summary statistics of the dataset
summary_statistics = data.describe()

missing_values, summary_statistics

# Filtering out rows that have -9999 in any of the columns
filtered_data_no_9999 = data[~(data == -9999).any(axis=1)]

# Comparing the shapes of the original and the filtered datasets to see how many rows were removed
original_shape = data.shape
filtered_no_9999_shape = filtered_data_no_9999.shape

original_shape, filtered_no_9999_shape
# Out:
# ((100000, 18), (99999, 18))

# %% [markdown]
# # **DATA STATS METHODS**
#
#
# ---
#
#
# * Data Distribution, Regression, and Correlation
#
# * ANOVA and Classification
#
# * Linear Discriminant Analysis
#
# * k-Nearest Neighbors
#
# * Linear Model Selection and Regularization
#
# * Principal Component Analysis
#
#
# ---
#
#
# * Clustering
#
# * Linear Regression
#
# * Logistic Regression

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

data = filtered_data_no_9999

# Encoding the 'class' column
label_encoder = LabelEncoder()
data['class_encoded'] = label_encoder.fit_transform(data['class'])

# Selecting relevant features for classification
# Assuming 'u', 'g', 'r', 'i', 'z', and 'redshift' are the relevant features for classification
features = data[['u', 'g', 'r', 'i', 'z', 'redshift']]
target = data['class_encoded']

# Scaling the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.3, random_state=42)

# Outputting the shape of the training and testing sets
(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# <ipython-input-10-a8c53568551f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['class_encoded'] = label_encoder.fit_transform(data['class'])
# ((69999, 6), (30000, 6), (69999,), (30000,))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# Training a Random Forest Classifier
random_forest_model = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest_model.fit(X_train, y_train)

# Predicting on the test set
y_pred = random_forest_model.predict(X_test)

# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred, target_names=label_encoder.classes_)

print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.9772333333333333

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# Re-creating the preprocessing steps
data = filtered_data_no_9999.copy()

# Encoding the 'class' column
label_encoder = LabelEncoder()
data['class_encoded'] = label_encoder.fit_transform(data['class'])

# Selecting relevant features for classification
features = data[['u', 'g', 'r', 'i', 'z', 'redshift']]
target = data['class_encoded']

# Scaling the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.3, random_state=42)

# Applying PCA
pca = PCA(n_components=2)  # Reducing to 2 dimensions for visualization purposes
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# Explained variance ratio for the two principal components
explained_variance_ratio = pca.explained_variance_ratio_

# Shapes of the transformed datasets
X_train_pca_shape = X_train_pca.shape
X_test_pca_shape = X_test_pca.shape

explained_variance_ratio, X_train_pca_shape, X_test_pca_shape
# Out:
# (array([0.74965702, 0.15610453]), (69999, 2), (30000, 2))

# %%
import numpy as np

# Plotting the PCA-transformed data
plt.figure(figsize=(10, 8))

# For better visualization, limit the number of points to plot
sample_size = 1000  # Sample size for each class
unique_classes = np.unique(y_train)
colors = ['red', 'green', 'blue']

for i, class_value in enumerate(unique_classes):
    # Filter the class
    indices = np.where(y_train == class_value)[0]
    # Randomly select sample_size indices for this class
    selected_indices = np.random.choice(indices, size=sample_size, replace=False)
    # Plot
    plt.scatter(X_train_pca[selected_indices, 0], X_train_pca[selected_indices, 1], alpha=0.5, label=label_encoder.inverse_transform([class_value])[0], color=colors[i])

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('2D PCA of the Dataset')
plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# Applying PCA with 3 components
pca_3d = PCA(n_components=3)
X_train_pca_3d = pca_3d.fit_transform(X_train)

# Plotting the 3D PCA-transformed data
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

for i, class_value in enumerate(unique_classes):
    # Filter the class
    indices = np.where(y_train == class_value)[0]
    # Randomly select sample_size indices for this class
    selected_indices = np.random.choice(indices, size=sample_size, replace=False)
    # Plot
    ax.scatter(X_train_pca_3d[selected_indices, 0], X_train_pca_3d[selected_indices, 1], X_train_pca_3d[selected_indices, 2], alpha=0.5, label=label_encoder.inverse_transform([class_value])[0], color=colors[i])

ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('3D PCA of the Dataset')
ax.legend()

plt.show()

# %%
# Calculating the total explained variance by the first two principal components
total_explained_variance = sum(explained_variance_ratio) * 100  # Convert to percentage

total_explained_variance
# Out:
# 90.57615468423255

# %%
# Retrieving the loadings (eigenvectors) for each PCA component
pca_loadings = pca.components_

# Creating a DataFrame for better visualization
pca_loadings_df = pd.DataFrame(pca_loadings, columns=features.columns, index=['PC1', 'PC2'])

pca_loadings_df
# Out:
#             u         g         r         i         z  redshift
# PC1 -0.365136 -0.441904 -0.463940 -0.454331 -0.437347 -0.241801
# PC2 -0.486352 -0.264616 -0.046952  0.101089  0.171976  0.807119

# %%
# Plotting the explained variance of each principal component

# Using the PCA model with 3 components (since it contains the first two as well)
explained_variance_ratio_3d = pca_3d.explained_variance_ratio_ * 100  # Convert to percentage

plt.figure(figsize=(8, 6))
plt.bar(range(1, len(explained_variance_ratio_3d) + 1), explained_variance_ratio_3d, color='skyblue')
plt.xlabel('Principal Components')
plt.ylabel('Percentage of Variance Explained')
plt.title('PCA - Variance Explained by Each Principal Component')
plt.xticks([1, 2, 3])
plt.show()

# %%
explained_variance_ratio_3d
# Out:
# array([74.96570175, 15.61045293,  7.27929578])

# %%
# Retrieving the loadings (eigenvectors) for each PCA component with 3 components
pca_loadings_3d = pca_3d.components_

# Creating a DataFrame for better visualization
pca_loadings_3d_df = pd.DataFrame(pca_loadings_3d, columns=features.columns, index=['PC1', 'PC2', 'PC3'])

pca_loadings_3d_df
# Out:
#             u         g         r         i         z  redshift
# PC1 -0.365136 -0.441904 -0.463940 -0.454331 -0.437347 -0.241801
# PC2 -0.486352 -0.264616 -0.046952  0.101089  0.171976  0.807119
# PC3  0.598420  0.154017 -0.156913 -0.332373 -0.440668  0.537485

# %%
# Visualizing the first two principal components

plt.figure(figsize=(10, 8))

# Plotting the PCA-transformed data
for i, class_value in enumerate(unique_classes):
    # Filter the class
    indices = np.where(y_train == class_value)[0]
    # Randomly select sample_size indices for this class
    selected_indices = np.random.choice(indices, size=sample_size, replace=False)
    # Plot
    plt.scatter(X_train_pca[selected_indices, 0], X_train_pca[selected_indices, 1], alpha=0.5, label=label_encoder.inverse_transform([class_value])[0], color=colors[i])

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('2D PCA of the Dataset')
plt.legend()
plt.show()

# %%
# Adding the third principal component to the visualization

fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

for i, class_value in enumerate(unique_classes):
    # Filter the class
    indices = np.where(y_train == class_value)[0]
    # Randomly select sample_size indices for this class
    selected_indices = np.random.choice(indices, size=sample_size, replace=False)
    # Plot
    ax.scatter(X_train_pca_3d[selected_indices, 0], X_train_pca_3d[selected_indices, 1], X_train_pca_3d[selected_indices, 2], alpha=0.5, label=label_encoder.inverse_transform([class_value])[0], color=colors[i])

ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('3D PCA of the Dataset')
ax.legend()

plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# Initialize the Random Forest Classifier
rf_classifier = RandomForestClassifier(random_state=42)

# Training the model using the first two principal components
rf_classifier.fit(X_train_pca, y_train)

# Predicting on the test set
y_pred = rf_classifier.predict(X_test_pca)

# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
classification_report_result = classification_report(y_test, y_pred, target_names=label_encoder.classes_)

accuracy, classification_report_result
# Out:
# (0.7977666666666666,
#  '              precision    recall  f1-score   support\n\n      GALAXY       0.80      0.89      0.84     17816\n         QSO       0.94      0.89      0.91      5742\n        STAR       0.63      0.46      0.53      6442\n\n    accuracy                           0.80     30000\n   macro avg       0.79      0.75      0.76     30000\nweighted avg       0.79      0.80      0.79     30000\n')

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the Logistic Regression model
log_reg = LogisticRegression(random_state=42)

# Training the model using the first two principal components
log_reg.fit(X_train_pca, y_train)

# Predicting on the test set
y_pred_log_reg = log_reg.predict(X_test_pca)

# Evaluating the model
accuracy_log_reg = accuracy_score(y_test, y_pred_log_reg)
classification_report_log_reg = classification_report(y_test, y_pred_log_reg, target_names=label_encoder.classes_)

accuracy_log_reg, classification_report_log_reg
# Out:
# (0.7519333333333333,
#  '              precision    recall  f1-score   support\n\n      GALAXY       0.71      0.97      0.82     17816\n         QSO       0.93      0.87      0.90      5742\n        STAR       0.64      0.03      0.06      6442\n\n    accuracy                           0.75     30000\n   macro avg       0.76      0.63      0.60     30000\nweighted avg       0.74      0.75      0.67     30000\n')

# %%
from sklearn.svm import SVC

# Initialize the Support Vector Classifier
svc = SVC(random_state=42)

# Training the model using the first two principal components
svc.fit(X_train_pca, y_train)

# Predicting on the test set
y_pred_svc = svc.predict(X_test_pca)

# Evaluating the model
accuracy_svc = accuracy_score(y_test, y_pred_svc)
classification_report_svc = classification_report(y_test, y_pred_svc, target_names=label_encoder.classes_)

accuracy_svc, classification_report_svc
# Out:
# (0.7936333333333333,
#  '              precision    recall  f1-score   support\n\n      GALAXY       0.76      0.97      0.85     17816\n         QSO       0.96      0.87      0.91      5742\n        STAR       0.76      0.24      0.37      6442\n\n    accuracy                           0.79     30000\n   macro avg       0.83      0.69      0.71     30000\nweighted avg       0.80      0.79      0.76     30000\n')

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
import numpy as np
import pandas as pd

# Load the dataset
file_path = 'star_classification.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset for an initial overview
data.head()

# Basic descriptive statistics for the dataset
descriptive_stats = data.describe()

# Checking for missing values in the dataset
missing_values = data.isnull().sum()

# Correlation analysis
correlation_matrix = data.corr()

# Class distribution
class_distribution = data['class'].value_counts()

# Prepare the analysis results
analysis_results = {
    "Descriptive Statistics": descriptive_stats,
    "Missing Values": missing_values,
    "Correlation Matrix": correlation_matrix,
    "Class Distribution": class_distribution
}

analysis_results


# Data Preparation
# Replacing -9999 values with NaN and then imputing them
data.replace(-9999, np.nan, inplace=True)
data.fillna(data.mean(), inplace=True)

# Defining features and target
X = data.drop(['class', 'obj_ID', 'spec_obj_ID', 'run_ID', 'rerun_ID', 'cam_col', 'field_ID', 'plate', 'MJD', 'fiber_ID'], axis=1)
y = data['class']

# Normalizing the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Simplifying models for quicker training
simplified_models = {
    "Logistic Regression": LogisticRegression(max_iter=100, random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=50, random_state=42),
    "Support Vector Machine": SVC(random_state=42),
    "Decision Tree": DecisionTreeClassifier(max_depth=5, random_state=42),
    "Neural Network": MLPClassifier(max_iter=100, random_state=42)
}

# Training and evaluating simplified models
simplified_model_results = {}
for name, model in simplified_models.items():
    # Train the model
    model.fit(X_train, y_train)

    # Predict on test set
    y_pred = model.predict(X_test)

    # Compute confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    simplified_model_results[name] = cm

# Plotting confusion matrices
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
fig.suptitle("Confusion Matrices for Different Models", fontsize=16)
axes = axes.flatten()

for ax, (name, cm) in zip(axes, simplified_model_results.items()):
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_title(name)
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')

# Adjust layout
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.show()
# Out:
# <ipython-input-6-b3cc39f9a57e>:29: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()
# <ipython-input-6-b3cc39f9a57e>:48: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean(), inplace=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
analysis_results

# %%
# Execute the provided code snippet to calculate the accuracies for each model

# Data Preparation
# Replacing -9999 values with NaN and then imputing them
data.replace(-9999, np.nan, inplace=True)
data.fillna(data.mean(), inplace=True)

# Defining features and target
X = data.drop(['class', 'obj_ID', 'spec_obj_ID', 'run_ID', 'rerun_ID', 'cam_col', 'field_ID', 'plate', 'MJD', 'fiber_ID'], axis=1)
y = data['class']

# Normalizing the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Simplifying models for quicker training
simplified_models = {
    "Logistic Regression": LogisticRegression(max_iter=100, random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=50, random_state=42),
    "Support Vector Machine": SVC(random_state=42),
    "Decision Tree": DecisionTreeClassifier(max_depth=5, random_state=42),
    "Neural Network": MLPClassifier(max_iter=100, random_state=42)
}

# Training and evaluating simplified models and calculating accuracies
accuracies = {}
for name, model in simplified_models.items():
    # Train the model
    model.fit(X_train, y_train)

    # Predict on test set
    y_pred = model.predict(X_test)

    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    accuracies[name] = accuracy

accuracies
# Out:
# <ipython-input-8-d7ca5ee1e090>:6: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean(), inplace=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Assuming X and y are already defined (features and target variable)
# Data Preparation
# Replacing -9999 values with NaN and then imputing them
data.replace(-9999, np.nan, inplace=True)
data.fillna(data.mean(), inplace=True)

# Defining features and target
X = data.drop(['class', 'obj_ID', 'spec_obj_ID', 'run_ID', 'rerun_ID', 'cam_col', 'field_ID', 'plate', 'MJD', 'fiber_ID'], axis=1)
y = data['class']

# Normalizing the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define the parameter grid for Random Forest
param_grid = {
    'n_estimators': [10, 50, 100, 200],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Create a RandomForestClassifier
rf = RandomForestClassifier(random_state=42)

# Instantiate the GridSearchCV object
rf_grid = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Fit the grid search to the data
rf_grid.fit(X_train, y_train)

# Print the best parameters and the best score
print("Best Parameters:", rf_grid.best_params_)
print("Best Score:", rf_grid.best_score_)

# Predict on the test data using the best model
y_pred = rf_grid.predict(X_test)

# Print classification report
print(classification_report(y_test, y_pred))
